# %% [markdown]
# # Convolutional Neural Network

# %%
import h5py
import numpy as np

def load_dataset():
    train_dataset = h5py.File('train_signs.h5', "r")
    train_set_x_orig = np.array(train_dataset["train_set_x"][:]) #  train features
    train_set_y_orig = np.array(train_dataset["train_set_y"][:]) #  train labels

    test_dataset = h5py.File('test_signs.h5', "r")
    test_set_x_orig = np.array(test_dataset["test_set_x"][:]) #  test features
    test_set_y_orig = np.array(test_dataset["test_set_y"][:]) #  test labels

    classes = np.array(test_dataset["list_classes"][:]) # list of classes
    
    train_set_y_orig = train_set_y_orig.reshape((train_set_y_orig.shape[0]),1)
    test_set_y_orig = test_set_y_orig.reshape((test_set_y_orig.shape[0],1))
    
    return train_set_x_orig, train_set_y_orig, test_set_x_orig, test_set_y_orig

# %%
#load your dataset here
X_train, Y_train, X_test, Y_test = load_dataset()

# %%
# Plot 
import matplotlib.pyplot as plt
# 20 random indicies
import random
samples = []
for i in range(20):
    samples.append(random.randint(0,len(X_train)))
samples
#plot in 4x5
plt.figure(figsize=(12,12))
for idx, item in enumerate(samples):
    plt.subplot(5, 4, idx+1)
    plt.imshow(X_train[item])
    plt.title(Y_train[item][0])
    plt.subplots_adjust(.5,.5,1,1,1,1)

# %%
# divide by the maximum possible value to scale down units 
X_train_new = X_train/255
X_test_new = X_test/255

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten, Dense, Conv2D, MaxPooling2D
import tensorflow as tf

# %%
model = Sequential()
model.add(Conv2D(32,kernel_size = (5,5),strides=(1,1), activation='relu', input_shape = X_train.shape[1:]))
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2)))
model.add(Conv2D(64, (5,5), activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Flatten())
model.add(Dense(1000, activation = 'relu'))
model.add(Dense(6, activation = 'softmax'))

# %%
model.compile(loss = 'SparseCategoricalCrossentropy', optimizer = 'adam', metrics = 'accuracy')

# %%
model.fit(X_train_new,Y_train, batch_size = 500, epochs = 100, validation_data = (X_test_new,Y_test))
# Out:
# Epoch 1/100
# 3/3 [==============================] - 4s 757ms/step - loss: 3.6336 - accuracy: 0.1546 - val_loss: 1.8354 - val_accuracy: 0.1667
# Epoch 2/100
# 3/3 [==============================] - 3s 772ms/step - loss: 1.8184 - accuracy: 0.1630 - val_loss: 1.7680 - val_accuracy: 0.2833
# Epoch 3/100
# 3/3 [==============================] - 3s 706ms/step - loss: 1.7563 - accuracy: 0.3185 - val_loss: 1.7739 - val_accuracy: 0.1667
# Epoch 4/100
# 3/3 [==============================] - 2s 694ms/step - loss: 1.7085 - accuracy: 0.3407 - val_loss: 1.6381 - val_accuracy: 0.3167
# Epoch 5/100
# 3/3 [==============================] - 2s 695ms/step - loss: 1.6362 - accuracy: 0.2898 - val_loss: 1.5497 - val_accuracy: 0.4583
# Epoch 6/100
# 3/3 [==============================] - 2s 685ms/step - loss: 1.4803 - accuracy: 0.4759 - val_loss: 1.4299 - val_accuracy: 0.4667
# Epoch 7/100
# 3/3 [==============================] - 2s 690ms/step - loss: 1.3624 - accuracy: 0.4731 - val_loss: 1.3946 - val_accuracy: 0.4583
# Epoch 47/100
# 3/3 [==============================] - 3s 759ms/step - loss: 0.0747 - accuracy: 0.9778 - val_loss: 0.2735 - val_accuracy: 0.9167
# Epoch 48/100
# 3/3 [==============================] - 3s 744ms/step - loss: 0.0765 - accuracy: 0.9852 - val_loss: 0.2022 - val_accuracy: 0.9333
# Epoch 49/100
# 3/3 [==============================] - 3s 750ms/step - loss: 0.0599 - accuracy: 0.9833 - val_loss: 0.2216 - val_accuracy: 0.9167
# Epoch 50/100
# 3/3 [==============================] - 3s 740ms/step - loss: 0.0556 - accuracy: 0.9889 - val_loss: 0.2043 - val_accuracy: 0.9417
# Epoch 51/100
# 3/3 [==============================] - 3s 694ms/step - loss: 0.0470 - accuracy: 0.9917 - val_loss: 0.1889 - val_accuracy: 0.9333
# Epoch 52/100
# 3/3 [==============================] - 3s 763ms/step - loss: 0.0465 - accuracy: 0.9889 - val_loss: 0.2142 - val_accuracy: 0.9167
# Epoch 53/100
# 3/3 [==============================] - 3s 711ms/step - loss: 0.0378 - accuracy: 0.9963 - val_loss: 0.1757 - val_accuracy: 0.9333
# Epoch 54/100
# 3/3 [==============================] - 2s 690ms/step - loss: 0.0344 - accuracy: 0.9972 - val_loss: 0.2050 - val_accuracy: 0.9333
# Epoch 55/100
# 3/3 [==============================] - 2s 691ms/step - loss: 0.0297 - accuracy: 0.9972 - val_loss: 0.1903 - val_accuracy: 0.9417
# Epoch 56/100
# 3/3 [==============================] - 2s 700ms/step - loss: 0.0354 - accuracy: 0.9972 - val_loss: 0.2289 - val_accuracy: 0.9333
# Epoch 57/100
# 3/3 [==============================] - 3s 719ms/step - loss: 0.0431 - accuracy: 0.9880 - val_loss: 0.2566 - val_accuracy: 0.9167
# Epoch 58/100
# 3/3 [==============================] - 3s 803ms/step - loss: 0.0341 - accuracy: 0.9981 - val_loss: 0.2147 - val_accuracy: 0.9333
# Epoch 59/100
# 3/3 [==============================] - 3s 713ms/step - loss: 0.0361 - accuracy: 0.9926 - val_loss: 0.2195 - val_accuracy: 0.9250
# Epoch 60/100
# 3/3 [==============================] - 3s 756ms/step - loss: 0.0292 - accuracy: 0.9991 - val_loss: 0.2035 - val_accuracy: 0.9333
# Epoch 61/100
# 3/3 [==============================] - 3s 739ms/step - loss: 0.0220 - accuracy: 1.0000 - val_loss: 0.2389 - val_accuracy: 0.9250
# Epoch 62/100
# 3/3 [==============================] - 3s 697ms/step - loss: 0.0211 - accuracy: 0.9991 - val_loss: 0.2228 - val_accuracy: 0.9333
# Epoch 63/100
# 3/3 [==============================] - 2s 684ms/step - loss: 0.0167 - accuracy: 1.0000 - val_loss: 0.2011 - val_accuracy: 0.9417
# Epoch 64/100
# 3/3 [==============================] - 2s 682ms/step - loss: 0.0187 - accuracy: 1.0000 - val_loss: 0.2041 - val_accuracy: 0.9333
# Epoch 65/100
# 3/3 [==============================] - 2s 689ms/step - loss: 0.0154 - accuracy: 1.0000 - val_loss: 0.1952 - val_accuracy: 0.9333
# Epoch 66/100
# 3/3 [==============================] - 3s 746ms/step - loss: 0.0137 - accuracy: 0.9991 - val_loss: 0.2353 - val_accuracy: 0.9250
# Epoch 67/100
# 3/3 [==============================] - 3s 737ms/step - loss: 0.0141 - accuracy: 1.0000 - val_loss: 0.2291 - val_accuracy: 0.9333
# Epoch 68/100
# 3/3 [==============================] - 2s 701ms/step - loss: 0.0131 - accuracy: 1.0000 - val_loss: 0.1936 - val_accuracy: 0.9333
# Epoch 69/100
# 3/3 [==============================] - 2s 690ms/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.1984 - val_accuracy: 0.9333
# Epoch 70/100
# 3/3 [==============================] - 3s 721ms/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.2040 - val_accuracy: 0.9333
# Epoch 71/100
# 3/3 [==============================] - 2s 709ms/step - loss: 0.0109 - accuracy: 1.0000 - val_loss: 0.1825 - val_accuracy: 0.9333
# Epoch 72/100
# 3/3 [==============================] - 3s 693ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.1956 - val_accuracy: 0.9417
# Epoch 73/100
# 3/3 [==============================] - 3s 698ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.2056 - val_accuracy: 0.9417
# Epoch 74/100
# 3/3 [==============================] - 2s 693ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.1932 - val_accuracy: 0.9333
# Epoch 75/100
# 3/3 [==============================] - 3s 812ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.2004 - val_accuracy: 0.9333
# Epoch 76/100
# 3/3 [==============================] - 3s 796ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.1928 - val_accuracy: 0.9333
# Epoch 77/100
# 3/3 [==============================] - 3s 711ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.1978 - val_accuracy: 0.9333
# Epoch 78/100
# 3/3 [==============================] - 2s 680ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.1935 - val_accuracy: 0.9417
# Epoch 79/100
# 3/3 [==============================] - 2s 681ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.1817 - val_accuracy: 0.9417
# Epoch 80/100
# 3/3 [==============================] - 2s 674ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.1803 - val_accuracy: 0.9417
# Epoch 81/100
# 3/3 [==============================] - 2s 687ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.1842 - val_accuracy: 0.9417
# Epoch 82/100
# 3/3 [==============================] - 2s 670ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.1932 - val_accuracy: 0.9417
# Epoch 83/100
# 3/3 [==============================] - 2s 689ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.1919 - val_accuracy: 0.9417
# Epoch 84/100
# 3/3 [==============================] - 2s 679ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.2078 - val_accuracy: 0.9333
# Epoch 85/100
# 3/3 [==============================] - 2s 680ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.2265 - val_accuracy: 0.9333
# Epoch 86/100
# 3/3 [==============================] - 2s 687ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.2055 - val_accuracy: 0.9333
# Epoch 87/100
# 3/3 [==============================] - 2s 688ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.1861 - val_accuracy: 0.9417
# Epoch 88/100
# 3/3 [==============================] - 2s 677ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.1940 - val_accuracy: 0.9417
# Epoch 89/100
# 3/3 [==============================] - 3s 721ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.2055 - val_accuracy: 0.9333
# Epoch 90/100
# 3/3 [==============================] - 3s 682ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.1877 - val_accuracy: 0.9417
# Epoch 91/100
# 3/3 [==============================] - 2s 692ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.1773 - val_accuracy: 0.9417
# Epoch 92/100
# 3/3 [==============================] - 2s 692ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.1916 - val_accuracy: 0.9417
# Epoch 93/100
# 3/3 [==============================] - 2s 685ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.2132 - val_accuracy: 0.9333
# Epoch 94/100
# 3/3 [==============================] - 2s 686ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.2024 - val_accuracy: 0.9333
# Epoch 95/100
# 3/3 [==============================] - 2s 686ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.1853 - val_accuracy: 0.9333
# Epoch 96/100
# 3/3 [==============================] - 2s 685ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.1830 - val_accuracy: 0.9417
# Epoch 97/100
# 3/3 [==============================] - 2s 683ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.1948 - val_accuracy: 0.9333
# Epoch 98/100
# 3/3 [==============================] - 2s 680ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.1928 - val_accuracy: 0.9417
# Epoch 99/100
# 3/3 [==============================] - 2s 675ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1823 - val_accuracy: 0.9417
# Epoch 100/100
# 3/3 [==============================] - 2s 667ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1963 - val_accuracy: 0.9333

# %%
model.summary
# Out:
# <bound method Model.summary of <keras.engine.sequential.Sequential object at 0x0000027E691BF130>>
